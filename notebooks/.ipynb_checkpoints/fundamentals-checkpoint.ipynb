# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../archive/companies-names-industries.csv')

df
# Out:
#         SEC ID               Latest Name Previous Names (@@@ separator)  \
# 0      1000045    Nicholas Financial Inc                            NaN
# 1      1000180              Sandisk Corp                            NaN
# 2      1000209  Medallion Financial Corp                            NaN
# 3      1000228          Henry Schein Inc                            NaN
# 4      1000229     Core Laboratories N V                            NaN
# ...        ...                       ...                            ...
# 12610    99313             Transnet Corp                            NaN
# 12611    99359       Breeze-Eastern Corp                            NaN
# 12612    99771      Trinity Capital Corp                            NaN
# 12613    99780    Trinity Industries Inc                            NaN
# 12614     9984          Barnes Group Inc                            NaN
#
#                       Latest NAICS Industry Sector Name  \
# ...

# %%
df.loc[df['SEC ID'] == 320193]
# Out:
#       SEC ID Latest Name Previous Names (@@@ separator)  \
# 9761  320193   Apple Inc                            NaN
#
#      Latest NAICS Industry Sector Name  Latest NAICS Industry Sector Code  \
# 9761                     Manufacturing                               33.0
#
#      Previous NAICS Industry Sector Names (@@@ separator)  \
# 9761                                                NaN
#
#      Previous NAICS Industry Sector Codes (@@@ separator)  \
# 9761                                                NaN
#
#       Latest SIC Industry Code Previous SIC Industry Codes (@@@ separator)
# 9761                    3571.0                                         NaN

# %%
df.loc[df['Latest Name'] =="Intel Corp"]
# Out:
#        SEC ID Latest Name Previous Names (@@@ separator)  \
# 10024   50863  Intel Corp                            NaN
#
#       Latest NAICS Industry Sector Name  Latest NAICS Industry Sector Code  \
# 10024                     Manufacturing                               33.0
#
#       Previous NAICS Industry Sector Names (@@@ separator)  \
# 10024                                                NaN
#
#       Previous NAICS Industry Sector Codes (@@@ separator)  \
# 10024                                                NaN
#
#        Latest SIC Industry Code Previous SIC Industry Codes (@@@ separator)
# 10024                    3674.0                                         NaN

# %%
df2 = pd.read_csv('../archive/metrics/Assets-quarterly.csv')

df2
# Out:
#         SEC ID        2011Q1        2011Q2        2011Q3        2011Q4  \
# 0      1003130           NaN  7.557800e+07  6.912600e+07  6.643300e+07
# 1      1133116           NaN  3.500000e+01  2.200000e+02  7.501300e+04
# 2       912513  3.826500e+09  3.857000e+09  3.630700e+09  3.536700e+09
# 3      1101026           NaN           NaN  3.660510e+05  4.634940e+05
# 4        23197  9.985630e+08  9.375090e+08  8.533730e+08           NaN
# ...        ...           ...           ...           ...           ...
# 10902  1391142           NaN           NaN  4.747110e+05  3.265900e+05
# 10903  1304409           NaN           NaN  4.802700e+05  4.864320e+05
# 10904  1163609           NaN  8.448095e+07  8.380843e+07  9.010743e+07
# 10905  1137411  5.020000e+09  5.113000e+09  5.389000e+09  5.168000e+09
# 10906    15393           NaN  3.377930e+08           NaN           NaN
#
#              2012Q1        2012Q2        2012Q3        2012Q4        2013Q1  \
# ...

# %%
df2.loc[df2['SEC ID'] ==320193]
# Out:
#       SEC ID        2011Q1        2011Q2        2011Q3        2011Q4  \
# 9722  320193  9.490400e+10  1.067580e+11  1.163710e+11  1.386810e+11
#
#             2012Q1        2012Q2        2012Q3        2012Q4        2013Q1  \
# 9722  1.509340e+11  1.628960e+11  1.760640e+11  1.960880e+11  1.947430e+11
#
#       ...        2015Q1        2015Q2        2015Q3        2015Q4  \
# 9722  ...  2.611940e+11  2.731510e+11  2.904790e+11  2.932840e+11
#
#             2016Q1        2016Q2        2016Q3        2016Q4  2017Q1  \
# 9722  3.052770e+11  3.056020e+11  3.216860e+11  3.311410e+11     NaN
#
#             2017Q2
# 9722  3.345320e+11
#
# [1 rows x 27 columns]

# %%
df3 = pd.read_csv('../archive/metrics/PropertyPlantAndEquipmentNet-quarterly.csv')

df3
# Out:
#         SEC ID        2011Q1        2011Q2        2011Q3        2011Q4  \
# 0      1003130           NaN  1.283200e+07  1.148100e+07  1.063700e+07
# 1      1133116           NaN           NaN           NaN  5.064000e+03
# 2       912513  1.123900e+09  1.132800e+09  1.105200e+09  1.114500e+09
# 3      1101026           NaN           NaN  1.247880e+05  8.354600e+04
# 4        23197  3.049100e+07  2.817700e+07  2.566100e+07           NaN
# ...        ...           ...           ...           ...           ...
# 10902  1391142           NaN           NaN  4.089800e+04  3.832500e+04
# 10903  1304409           NaN           NaN           NaN           NaN
# 10904  1163609           NaN  2.744918e+07  2.718044e+07  2.639831e+07
# 10905  1137411  7.180000e+08  7.290000e+08  7.540000e+08  7.460000e+08
# 10906    15393           NaN  1.070390e+08           NaN           NaN
#
#              2012Q1       2012Q2       2012Q3       2012Q4       2013Q1  ...  \
# ...

# %%
df3.loc[df3['SEC ID'] ==320193]
# Out:
#       SEC ID  2011Q1  2011Q2  2011Q3  2011Q4        2012Q1        2012Q2  \
# 9722  320193     NaN     NaN     NaN     NaN  8.847000e+09  1.048700e+10
#
#             2012Q3        2012Q4        2013Q1  ...        2015Q1  \
# 9722  1.545200e+10  1.542200e+10  1.502600e+10  ...  2.015100e+10
#
#             2015Q2        2015Q3        2015Q4        2016Q1        2016Q2  \
# 9722  2.114900e+10  2.247100e+10  2.230000e+10  2.320300e+10  2.544800e+10
#
#             2016Q3        2016Q4  2017Q1        2017Q2
# 9722  2.701000e+10  2.651000e+10     NaN  2.716300e+10
#
# [1 rows x 27 columns]

# %%
df4 = pd.read_csv('../archive/metrics/latest-snapshot-quarterly.csv')

df4
# Out:
#         SEC ID Report date        Assets  AssetsCurrent  \
# 0      1329548  2012-09-30  1.506650e+05   1.409890e+05
# 1      1205727  2014-03-31  2.434050e+08   6.298800e+07
# 2      1555560  2013-11-30  2.360000e+02            NaN
# 3      1008848  2017-03-31  1.319842e+09   2.481520e+08
# 4       316793  2014-09-28  1.585348e+09   1.069869e+09
# ...        ...         ...           ...            ...
# 10901    29669  2017-03-31  3.907300e+09   2.138000e+09
# 10902  1543637  2017-03-31  3.497480e+05   3.284530e+05
# 10903  1047881  2017-03-31  2.025767e+07   9.547806e+06
# 10904  1546296  2017-03-31  3.996409e+07   9.309830e+06
# 10905  1041577  2013-12-31  5.962200e+08   4.233370e+08
#
#        CashAndCashEquivalentsAtCarryingValue  ComprehensiveIncomeNetOfTax  \
# 0                                        NaN                          NaN
# 1                                 26265000.0                          NaN
# ...

# %%
df4.loc[df4['SEC ID'] ==320193]
# Out:
#       SEC ID Report date        Assets  AssetsCurrent  \
# 6691  320193  2017-04-01  3.345320e+11   1.019900e+11
#
#       CashAndCashEquivalentsAtCarryingValue  ComprehensiveIncomeNetOfTax  \
# 6691                           1.515700e+10                 1.036200e+10
#
#       EarningsPerShareDiluted      Goodwill   Liabilities  LiabilitiesCurrent  \
# 6691                      2.1  5.473000e+09  2.004500e+11        7.334200e+10
#
#       NetCashProvidedByUsedInFinancingActivities  \
# 6691                                         NaN
#
#       NetCashProvidedByUsedInInvestingActivities  \
# 6691                                         NaN
#
#       NetCashProvidedByUsedInOperatingActivities  OperatingIncomeLoss  \
# 6691                                         NaN         1.409700e+10
#
#       PropertyPlantAndEquipmentNet      Revenues  \
# 6691                  2.716300e+10  5.289600e+10
#
#       WeightedAverageNumberOfDilutedSharesOutstanding
# ...

# %%
df5 = pd.read_csv('../archive/companies/320193-quarterly.csv')

df5.head(40)
# Out:
#                                            Unnamed: 0    2011-03-26  \
# 0              AllocatedShareBasedCompensationExpense           NaN
# 1   AntidilutiveSecuritiesExcludedFromComputationO...  2.200000e+05
# 2        CashAndCashEquivalentsPeriodIncreaseDecrease           NaN
# 3                CommonStockDividendsPerShareDeclared           NaN
# 4                         ComprehensiveIncomeNetOfTax  5.999000e+09
# 5                          CostOfGoodsAndServicesSold  1.444900e+10
# 6                     DeferredIncomeTaxExpenseBenefit           NaN
# 7             DepreciationAmortizationAndAccretionNet           NaN
# 8   DerivativeInstrumentsGainLossReclassifiedFromA... -9.000000e+07
# 9   DerivativeInstrumentsGainLossRecognizedInIncom... -1.400000e+08
# 10  DerivativeInstrumentsGainLossRecognizedInOther... -2.270000e+08
# 11  DerivativeInstrumentsNotDesignatedAsHedgingIns... -8.400000e+07
# 12                              EarningsPerShareBasic  6.490000e+00
# ...
